# %%
import os
from lexoid.api import parse
from IPython.display import display, Image, Markdown

os.environ["GOOGLE_API_KEY"] = "AIzaSyA0Vn_uIF2aRUe2z8jdNM9x0iJdprgeEiY"

# %%
document_path = r"V:\02. Desenvolvimento\Projetos - Dev\UniqueAduaneira\uniq_adu_portal\static\uploads\conferencia\20250809_135824_Invoice_935917.pdf"
parsed_md = parse(document_path, "LLM_PARSE")["raw"]
# Out:
# 2025-08-09 15:24:55.935 | DEBUG    | lexoid.api:parse_chunk:114 - Using LLM parser

# %%
display(Markdown(parsed_md))
# Out:
# ORIGINAL
# <table style="border: none;">
#   <tr>
#     <td style="text-align: left;">
#       LCK.
#       <br>
#       METALL
#     </td>
#     <td style="text-align: right;">
#       <img src="" alt="LCK Metall logo" width="150"/>
#     </td>
#   </tr>
# </table>
#
# LCK. METALL - Lise-Meitner-Str. 6-8 - 24558 Henstedt-Ulzburg
#
# Aguas Azuis Construcao Naval SPE LTDA
# <br>
# R Eugenio Pezzini 355 SL 5 Cordeiros
# <br>
# 88311-000 Itajai
# <br>
# BRASILIEN
#
# <div style="text-align: right;">Invoice <b>935917</b></div>
#
# <table style="border: none;">
#   <tr>
#     <td>Date:</td>
#     <td>15.02.2024</td>
#     <td style="text-align: right;">Page: 1</td>
#   </tr>
#   <tr>
#     <td>Customer no:</td>
#     <td>157872</td>
#   </tr>
#   <tr>
#     <td>Your VAT no:</td>
#     <td></td>
#   </tr>
#   <tr>
#     <td>Your contact:</td>
#     <td>Tanja Landsmann</td>
#   </tr>
#   <tr>
#     <td>Extension:</td>
#     <td>04193 9995-21</td>
#   </tr>
# </table>
#
# ...
